# %%
from urllib.request import urlopen
import time
import json

# %%
urls = [
"powerade.ca",
"coca-cola.ge",
"coke.at/de/home",
"coke.com.tw/zh/home",
"chaywa.co.za/en/home",
"fanta.co.id/id/home",
"wilkinswater.com/en/home",
"minutemaid.ca",
"pl.woah.com/pl/home",
"en.cocacola.co.id",
"spritesa.co.za/en/home",
"coca-colajourney.co.nz",
"damlasu.com.tr/tr/home",
"melloyello.com",
"appletiser.com/en/home",
"sprite.in",
"tn.sprite.com/fr/home",
"coca-cola.com.co/es/sv/home",
"minutemaid.com.tw",
"zm.coca-cola.com/en/home",
"cepita.com.ar/es/home",
"cocacola.dk/da/home",
"fanta.com",
"register.coca-cola.com/ro",
"spritelatinamerica.com/es/home",
"mmaid.jp/jp/home",
"coca-cola.com.ar/es/home",
"fanta.lat/es/home",
"powerade.ru/ru/home",
"pncta.com.mx",
"sprite.lat/es/ec/home",
"coca-colaitalia.it",
"smartwatercanada.ca",
"register.coca-cola.com/ch",
"coca-cola.cz/cs/home",
"coca-cola.lt/lt/home",
"summersipsquad.coca-cola.com",
"dogadan.com.tr",
"coca-colajourney.com.pk",
"fantalatinamerica.com/es/ar/home",
"cocacolafm.com.br",
"drinkhonest.fr/fr/home",
"sanluis.com.pe/es/home",
"spielplatzinitiative.fanta.de",
"register.coca-cola.com/fi",
"register.fanta.com/rs",
"scanacoke.nl",
"fr.coca-colamaroc.ma",
"sprite.com.pk",
"c.cocacola.co.jp/schweppes",
"coca-cola.it/it/home",
"manantial.com.co/es/home",
"sprite.bg/bg/home",
"preguntasyrespuestas.cocacolaespana.es",
"coca-coladeuruguay.com.uy",
"register.coca-cola.com/de",
"en.cocacolavietnam.com",
"sprite.lat/es/gt/home",
"coca-colarussia.ru",
"coke.ch/fr/home",
"coca-cola.dz/fr/home",
"sprite.eg/en/home",
"sprite.com.br/pt/home",
"spritelatinamerica.com/es/cl/home",
"preguntasyrespuestas.coca-cola.com/es/home",
"hansens.com",
"hubertslemonade.com",
"sprite.lat/es/hn/home",
"register.coca-cola.com/pt",
"georgia.jp",
"coca-cola.me/sr/home",
"appletiser.com/pt/pt/home",
"cocacola.no/no/home",
"cn.icoke.com/zh/home",
"dasani.com",
"sokenbicha.jp",
"cocacola.com.mt/en/home",
"tn.coca-colalight.com/fr/home",
"spritelatinamerica.com/es/ar/home",
"cocacoladeperu.com.pe",
"coca-cola.com.uy/es/home",
"cupacocacola.ro",
"coca-colarussia.ru",
"fanta.com.au",
"peace-tea.ca",
"vitaminwater.tumblr.com",
"vitaminwater.tumblr.com",
"coca-cola.ma/fr/home",
"poweradelatinamerica.com/es/home",
"tz.minutemaid.com/en/home",
"schweppes.com.ar/es/home",
"us.coca-cola.com",
"cocacoladeperu.com.pe",
"et.coca-cola.com/en/home",
"coca-colasrbija.rs",
"coca-colajourney.com.pk",
"cocacolaportugal.pt",
"sprite.lat/es/sv/home",
"register.fanta.com/ro",
"odwalla.com",
"coca-cola.com.co/en/cx/home",
"welcome.coke.com",
"coca-colaentuhogar.com",
"coca-colaentuhogar.com",
"register.coca-cola.com/se",
"fr.coca-colamaroc.ma",
"frugosdelvalle.com.pe/es/home",
"yogurstand.jp/jp/home",
"coca-coladeuruguay.com.uy",
"fanta.lat/es/ni/home",
"reg.cocacola.co.jp/login/index.htm",
"cocacola.jp",
"coca-cola.lv/lv/home",
"fuze-tea.com.ar/es/home",
"appletiser.com/za/en/home",
"coca-colaafrica.com",
"coca-cola.az/az/home",
"coca-cola.ro/ro/home",
"fanta.ma/fr/home",
"drinkhonest.be/nl/home",
"cocacola.nl/nl/home",
"sprite.com",
"company.cocacola.co.kr",
"coca-cola.com.co/es/cr/home",
"coca-cola.co.ug/en/home",
"coca-cola.ee/et/home",
"nestea.ca/en/home",
"register.coca-cola.com/it",
"fanta.lat/es/ec/home",
"fanta.co.kr/ko/home",
"star.5by20.com/vn/vi/home",
"spritelatinamerica.com/es/pe/home",
"fr.coca-cola.ca",
"spritelatinamerica.com/es/py/home",
"coca-coladeparaguay.com.py",
"coca-cola.fi",
"coca-cola.mu/en/home",
"georgiacoffee.kr/ko/home",
"loja.cocacola.com.br",
"sprite.lat/es/do/home",
"powerade.co.za/en/home",
"c.cocacola.co.jp/sprite",
"coca-colamexico.com.mx",
"fanta.com.tr/tr/home",
"fr.coca-cola.ca",
"promociones.coca-cola.com.mx",
"sprite.lat/es/ni/home",
"sprite.lat/es/cr/home",
"xmas.coca-cola.by",
"coca-cola.fi"
]

apikey = "A.3d017d4a81680e7303fc871284656521"

fdata = [("url","visual_complete")]

# %%
data = [("url","visual_complete")]
def wus(link):
    time.sleep(60)
    report = urlopen(link)
    report_html = report.read()
    report_json = json.loads(report_html)
    vcode = report_json['statusCode']
    print("Status Code:",vcode)
    if vcode!= 200:
        wus(link)
        
    dd1 = urlopen(link)
    dd2 = dd1.read()
    dd3 = json.loads(dd2)
    
    dd4 = dd3["data"]["average"]["firstView"]["visualComplete"] 
    
    dd5 = int(dd4)
    tp = (i, dd5)
    
    
    return tp

# %%
def condi(code,i,apikey,d):
    print(code)
    if code != 200:
        time.sleep(10)
        q = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
        data = html.read()
        d = json.loads(data)
        code = d['statusCode']
        condi(code, i, apikey,d)
    else:
        print("1st done")
        link =d['data']['jsonUrl']
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        if vcode!= 200:
            dd = wus(link)
        print(dd)
        return(dd)

# %%
big_list = [("url","visualComplete")]

for i in urls:
    html = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
    data = html.read()
    d = json.loads(data)
    code = d['statusCode']
    try:
        tpl = condi(code,i,apikey,d)
    except Exception:
        pass
    big_list.append(tpl)
print("BBIIIGGG LIIISSSSTTT",big_list)
# Out:
# 200
# 1st done
# Status Code: 101
# Status Code: 200
# ('powerade.ca', 2100)
# 200
# 1st done
# Status Code: 200
# ('coca-cola.ge', 3700)
# 200
# 1st done
# Status Code: 200
# ('coke.at/de/home', 6200)
# 200
# 1st done
# Status Code: 200
# ('coke.com.tw/zh/home', 8600)
# 200
# 1st done
# Status Code: 200
# ('chaywa.co.za/en/home', 4900)
# 200
# 1st done
# Status Code: 200
# ('fanta.co.id/id/home', 4200)
# 200
# 1st done
# Status Code: 200
# ('wilkinswater.com/en/home', 5500)
# 200
# 1st done
# Status Code: 200
# ('minutemaid.ca', 4800)
# 200
# 1st done
# Status Code: 200
# ('pl.woah.com/pl/home', 4200)
# 200
# 1st done
# Status Code: 200
# ('en.cocacola.co.id', 5400)
# 200
# 1st done
# Status Code: 200
# ('spritesa.co.za/en/home', 8800)
# 200
# 1st done
# Status Code: 200
# ('coca-colajourney.co.nz', 5800)
# 200
# 1st done
# Status Code: 200
# ('damlasu.com.tr/tr/home', 5200)
# 200
# 1st done
# Status Code: 101
# Status Code: 101
# Status Code: 100
# Status Code: 200
# ...

# %%
import csv
with open('WebPageTestIterationX1.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile)
    wr.writerows(big_list)
