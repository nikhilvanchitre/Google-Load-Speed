# %%
from urllib.request import urlopen
import time
import json

# %%
urls = ["http://www.hubertslemonade.com",
"http://www.parklives.com",
"https://www.cocacola.nl/nl/home/"
]

apikey = "A.6d9a13e3718a07a676ba85d73817d46a"

fdata = [("url","visual_complete")]

# %%
def wus(link):
    time.sleep(60)
    report = urlopen(link)
    report_html = report.read()
    report_json = json.loads(report_html)
    vcode = report_json['statusCode']
    print("Status Code:",vcode)
    if vcode!= 200:
        wus(link)
        
    dd1 = urlopen(link)
    dd2 = dd1.read()
    dd3 = json.loads(dd2)
    dd4 = dd3['data']['average']['firstView']['visualComplete']
    dd5 = int(dd4)
    
    return dd5

# %%
def condi(code,i,apikey,d):
    print(code)
    if code != 200:
        time.sleep(10)
        q = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
        data = html.read()
        d = json.loads(data)
        code = d['statusCode']
        condi(code, i, apikey,d)
    else:
        print("1st done")
        link =d['data']['jsonUrl']
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        if vcode!= 200:
            dd = wus(link)
        print("Visual Complete:",dd)

# %%
for i in urls:
    html = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
    data = html.read()
    d = json.loads(data)
    code = d['statusCode']
    condi(code,i,apikey,d)
# Out:
# 200
# 1st done
# Status Code: 100
# Status Code: 100
# Status Code: 200
# Visual Complete: 15900
# 200
# 1st done
# Status Code: 100
# Status Code: 200
# Visual Complete: 6600
# 200
# 1st done
# Status Code: 100
# Status Code: 200
# Visual Complete: 23700

# %%
##########################################################################################################################

# %%
def cond(code,i,apikey,d):
    print(code)
    if code != 200:
        time.sleep(10)
        q = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
        data = html.read()
        d = json.loads(data)
        code = d['statusCode']
        cond(code, i, apikey,d)
    else:
        print("test not completed. wait 2 mins")
        time.sleep(120)
        link =d['data']['jsonUrl']
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        print("vcode:",vcode)
        if vcode != 200:
            print("test still incomplete. Waiting for another 1 min")
            time.sleep(60)
        else:
            print("successful!")
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        print("vcode2:",vcode)
        if vcode != 200:
            print("test still incomplete. Waiting for another 1 min")
            time.sleep(60)
        else:
            print("Successful!!")
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        print("vcode3:",vcode)

# %%
for i in urls:
    html = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
    data = html.read()
    d = json.loads(data)
    code = d['statusCode']
    condi(code,i,apikey,d)
# Out:
# 200
# 1st done
# Status Code: 101
# Status Code: 101
# Status Code: 100
# Status Code: 100
# Status Code: 100
# Status Code: 200
# 16200
# 200
# 1st done
# Status Code: 100
# Status Code: 200
# 8600
# 200
# 1st done
# Status Code: 100
# Status Code: 200
# 21500

# %%
***********************************************************************

# %%
if code!=200:
        time.sleep(10)
        html = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
        time.sleep(10)
        data = html.read()
        d = json.loads(data)
        code = d['statusCode']
        print(code)
        
    link =d['data']['jsonUrl']
    time.sleep(20)
    report = urlopen(link)
    report_html = report.read()
    report_json = json.loads(report_html)
    print(report_json)
    report_onesite = report_json['data']['average']['firstView']['visualComplete']
    print(report_onesite)

# %%
 record = report_onesite, url
    
    report_data = report_html.read()
    print(report_data)
    
    r_json = json.loads(report_data)
    x = r_json['data']['statusCode']
    
    if x != 200:
        time.sleep(10)
    
    report_data = report_html.read()

# %%
 if x == 200:
        
    else:
        time.sleep(10)
        if x == 200:
            report_onesite = r_json['data']['average']['firstView']['visualComplete']
            record = report_onesite, url
            print(record)
        else:
            time.sleep(10)
            report_onesite = r_json['data']['average']['firstView']['visualComplete']
            record = report_onesite, url
            print(record)
# Out:
# [('url', 'visual_complete')]

# %%
#cancel last para for a broader report
    report_json = json.loads(report_data)
    report_onesite = report_json['data']['average']['firstView']['visualComplete']
    record = report_onesite, url
    fdata.append(record)

# %%
html = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+url+"&k="+apikey)
# Out:
# http.client.HTTPResponse

# %%
data = html.read()
# Out:
# b'{"statusCode":200,"statusText":"Ok","data":{"testId":"181010_CV_f2a11e3861e6f4796cea111930f1128d","ownerKey":"a83bdb61cabaf38061b3dbe9ba5175a3380d949f","jsonUrl":"https:\\/\\/www.webpagetest.org\\/jsonResult.php?test=181010_CV_f2a11e3861e6f4796cea111930f1128d","xmlUrl":"https:\\/\\/www.webpagetest.org\\/xmlResult\\/181010_CV_f2a11e3861e6f4796cea111930f1128d\\/","userUrl":"https:\\/\\/www.webpagetest.org\\/result\\/181010_CV_f2a11e3861e6f4796cea111930f1128d\\/","summaryCSV":"https:\\/\\/www.webpagetest.org\\/result\\/181010_CV_f2a11e3861e6f4796cea111930f1128d\\/page_data.csv","detailCSV":"https:\\/\\/www.webpagetest.org\\/result\\/181010_CV_f2a11e3861e6f4796cea111930f1128d\\/requests.csv"}}'

# %%
import json
d = json.loads(data)
link = d['data']['jsonUrl']

# %%
# Out:
# 'https://www.webpagetest.org/jsonResult.php?test=181010_CV_f2a11e3861e6f4796cea111930f1128d'

# %%
report_html = urlopen(link)
time.sleep(20)
report_data = report_html.read()
# Out:
# b'{"data":{"id":"181010_CV_f2a11e3861e6f4796cea111930f1128d","url":"https:\\/\\/www.coca-colaindia.com","summary":"https:\\/\\/www.webpagetest.org\\/results.php?test=181010_CV_f2a11e3861e6f4796cea111930f1128d","testUrl":"https:\\/\\/www.coca-colaindia.com","location":"Dulles:Chrome","from":"Dulles, VA - <b>Chrome<\\/b> - <b>Cable<\\/b>","connectivity":"Cable","bwDown":5000,"bwUp":1000,"latency":28,"plr":"0","mobile":0,"completed":1539191309,"tester":"VM2-04-192.168.11.101","runs":{"1":{"firstView":{"numSteps":1,"run":1,"tester":"VM2-04-192.168.11.101","minify_total":-1,"responses_200":185,"testStartOffset":0,"bytesOut":141755,"gzip_savings":1697,"requestsFull":220,"start_epoch":0,"connections":53,"base_page_cdn":"Akamai","bytesOutDoc":115333,"result":0,"final_base_page_request_id":"009F94AAF9B5AF1CD79BAC51F9A3924D","score_cookies":-1,"basePageSSLTime":133,"docTime":12262,"domContentLoadedEventEnd":2085,"image_savings":997636,"requestsDoc":177,"firstMeaningfulPaint":2811,"firstTextPaint":1478,"firstPaint":1477.5999999983,"score_cdn":98,"optimization_checked":1,"image_total":5743168,"score_minify":-1,"gzip_total":6152945,"responses_404":0,"loadTime":12262,"URL":"https:\\/\\/www.coca-colaindia.com","score_combine":-1,"firstContentfulPaint":1478,"firstLayout":1119,"score_etags":-1,"loadEventStart":12261,"minify_savings":-1,"score_progressive_jpeg":4,"domInteractive":2072,"score_gzip":100,"score_compress":83,"domContentLoadedEventStart":2072,"final_url":"https:\\/\\/www.coca-colaindia.com\\/","bytesInDoc":6345207,"firstImagePaint":1749,"score_keep-alive":100,"loadEventEnd":12263,"cached":0,"score_cache":58,"responses_other":35,"main_frame":"A97216DD73D42AAD416FF2501BD2E84F","fullyLoaded":13764,"requests":[{"ip_addr":"104.96.218.197","initiator_line":"","bytesOut":400,"load_ms":186,"final_base_page":true,"request_id":"009F94AAF9B5AF1CD79BAC51F9A3924D","image_save":null,"minify_total":null,"chunks":[{"bytes":3371,"ts":407.385},{"bytes":12288,"ts":414.218},{"bytes":7727,"ts":434.565}],"cacheControl":"max-age=0, no-cache","score_cdn":100,"certificates":["-----BEGIN CERTIFICATE-----\\nMIIIizCCB3OgAwIBAgIRANiTJqlBiGpSAAAAAFgH7YcwDQYJKoZIhvcNAQELBQAw\\ngYIxCzAJBgNVBAYTAkNBMRQwEgYDVQQKEwtBZmZpcm1UcnVzdDErMCkGA1UECxMi\\nU2VlIHd3dy5hZmZpcm10cnVzdC5jb20vcmVwb3NpdG9yeTEwMC4GA1UEAxMnQWZm\\naXJtVHJ1c3QgQ2VydGlmaWNhdGUgQXV0aG9yaXR5IC0gT1YxMB4XDTE3MDUwMjE4\\nMzUyNVoXDTE5MDUwMzE5MDUxN1owbjELMAkGA1UEBhMCVVMxEDAOBgNVBAgTB0dl\\nb3JnaWExEDAOBgNVBAcTB0F0bGFudGExHjAcBgNVBAoTFVRoZSBDb2NhLUNvbGEg\\nQ29tcGFueTEbMBkGA1UEAxMSYWVtMS5jb2NhLWNvbGEuY29tMIIBIjANBgkqhkiG\\n9w0BAQEFAAOCAQ8AMIIBCgKCAQEAqXtix3pSb1\\/ukQQbi373FZEju2DiqMGeszE\\/\\nOWCa2xXNnLZRW8aglDwia+TlP+Fp3xTW2yDavRZ+eB3410orReNTZKt\\/8o+JOAqD\\nWRRKa5ra0wTosOmFkQdXxOBfG9E5FaI6x23ewUx2LxiBF7wyQJQDwhmBajPLGu6\\/\\nqDCK4sCOdmuN4GBY7VbcbLRTdCCG0sXwwt5we8jfhQvcH3thlMewzxgfcXccxMGF\\nDrXgp+BcXUQcq6Czs3fUYgzfDtIXX1d4JYwV0Exqc2LiyOIanEZ9qe8Ah5u3l0J4\\nvdGOlwNB6zU7+rmiQuHr2BzZIL08zsCFXyyBl+RtA7TvDub4iwIDAQABo4IFDTCC\\nBQkwDgYDVR0PAQH\\/BAQDAgWgMB0GA1UdJQQWMBQGCCsGAQUFBwMBBggrBgEFBQcD\\nAjAJBgNVHRMEAjAAMGwGCCsGAQUFBwEBBGAwXjAnBggrBgEFBQcwAYYbaHR0cDov\\nL29jc3AuYWZmaXJtdHJ1c3QuY29tMDMGCCsGAQUFBzAChidodHRwOi8vYWlhLmFm\\nZmlybXRydXN0LmNvbS9hZnRvdjFjYS5jcnQwVwYDVR0gBFAwTjBCBgorBgEEAYKP\\nCQIFMDQwMgYIKwYBBQUHAgEWJmh0dHBzOi8vd3d3LmFmZmlybXRydXN0LmNvbS9y\\nZXBvc2l0b3J5MAgGBmeBDAECAjA8BgNVHR8ENTAzMDGgL6AthitodHRwOi8vY3Js\\nLmFmZmlybXRydXN0LmNvbS9jcmwvYWZ0b3YxY2EuY3JsMIIDhgYDVR0RBIIDfTCC\\nA3mCEmFlbTEuY29jYS1jb2xhLmNvbYIWYXIuY29jYS1jb2xhYXJhYmlhLmNvbYIW\\nZW4uY29jYS1jb2xhYXJhYmlhLmNvbYIPZnIuY29jYS1jb2xhLmNhghRmci5jb2Nh\\nLWNvbGFtYXJvYy5tYYIVam91cm5leS5jb2NhLWNvbGEuY29tghx3d3cuY29jYS1j\\nb2xhLWRldXRzY2hsYW5kLmRlghd3d3cuY29jYS1jb2xhLWZyYW5jZS5mcoIQd3d3\\nLmNvY2EtY29sYS5jYYITd3d3LmNvY2EtY29sYS5jby51a4IQd3d3LmNvY2EtY29s\\nYS5ka4IQd3d3LmNvY2EtY29sYS5maYIQd3d3LmNvY2EtY29sYS5pZYIQd3d3LmNv\\nY2EtY29sYS5ub4IQd3d3LmNvY2EtY29sYS5zZYIYd3d3LmNvY2EtY29sYWNvbXBh\\nbnkuY29tghZ3d3cuY29jYS1jb2xhaW5kaWEuY29tghZ3d3cuY29jYS1jb2xhaXRh\\nbG ...

# %%
#cancel last para for a broader report
report_json = json.loads(report_data)
report_onesite = report_json['data']['average']['firstView']['visualComplete']
record = report_onesite, url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1be5360d2211> in <module>()
#       1 #cancel last para for a broader report
# ----> 2 report_json = json.loads(report_data)
#       3 report_onesite = report_json['data']['average']['firstView']['visualComplete']
#       4 record = report_onesite, url
#
# NameError: name 'json' is not defined

# %%
# Out:
# int

# %%
import pandas as pd
data_onesite = pd.DataFrame.from_dict(list(report_onesite.items()))
print(data_onesite)
data_onesite.to_csv('WebPageResult.csv')
# Out:
#                                                  0          1
# 0                                     minify_total       -1.0
# 1                                    responses_200      186.0
# 2                                  testStartOffset        0.0
# 3                                         bytesOut   141478.0
# 4                                     gzip_savings     1695.0
# 5                                     requestsFull      221.0
# 6                                      start_epoch        0.0
# 7                                      connections       52.0
# 8                                      bytesOutDoc   138016.0
# 9                                           result        0.0
# 10                                   score_cookies       -1.0
# 11                                 basePageSSLTime       79.0
# 12                                         docTime    13059.0
# 13                        domContentLoadedEventEnd     2235.0
# 14                                   image_savings  1045353.0
# 15                                     requestsDoc      215.0
# 16                            firstMeaningfulPaint     2296.0
# 17                                  firstTextPaint     1357.0
# 18                                      firstPaint     1355.7
# 19                                       score_cdn       99.0
# 20                            optimization_checked        1.0
# 21                                     image_total  5797835.0
# 22                                    score_minify       -1.0
# 23                                      gzip_total  6206218.0
# 24                                   responses_404        0.0
# 25                                        loadTime    13059.0
# 26                                   score_combine       -1.0
# 27                            firstContentfulPaint     1357.0
# 28                                     firstLayout      986.0
# 29                                     score_etags       -1.0
# ..                                             ...        ...
# 67               chromeUserTiming.unloadEventStart      219.0
# 68                 chromeUserTiming.unloadEventEnd      219.0
# 69                     chromeUserTiming.domLoading      224.0
# 70                    chromeUserTiming.responseEnd      231.0
# 71                    chromeUserTiming.firstLayout      985.0
# 72           chromeUserTiming.firstContentfulPaint     1356.0
# 73                 chromeUserTiming.firstTextPaint     1356.0
# 74  chromeUserTiming.firstMeaningfulPaintCandidate     2295.0
# 75                     chromeUserTiming.firstPaint     1356.0
# 76                chromeUserTiming.firstImagePaint     1493.0
# 77                 chromeUserTiming.domInteractive     2224.0
# 78     chromeUserTiming.domContentLoadedEventStart     2224.0
# 79       chromeUserTiming.domContentLoadedEventEnd     2235.0
# 80           chromeUserTiming.firstMeaningfulPaint     2295.0
# 81                    chromeUserTiming.domComplete    13058.0
# 82                 chromeUserTiming.loadEventStart    13059.0
# 83                   chromeUserTiming.loadEventEnd    13060.0
# 84                                             run        1.0
# 85                                            step        1.0
# 86                                    effectiveBps   506606.0
# 87                                 effectiveBpsDoc   529237.0
# 88                                         domTime        0.0
# 89                                             aft        0.0
# 90                                       titleTime        0.0
# 91                                      domLoading        0.0
# 92                                      server_rtt        0.0
# 93                                 smallImageCount       29.0
# 94                                   bigImageCount       14.0
# 95                                    maybeCaptcha        0.0
# 96                                          avgRun        1.0
#
# [97 rows x 2 columns]

# %%
def condi(code,i,apikey,d):
    print(code)
    if code != 200:
        time.sleep(10)
        q = urlopen("https://www.webpagetest.org/runtest.php?f=json&url="+i+"&k="+apikey)
        data = html.read()
        d = json.loads(data)
        code = d['statusCode']
        condi(code, i, apikey,d)
    else:
        print("1st done")
        link =d['data']['jsonUrl']
        report = urlopen(link)
        report_html = report.read()
        report_json = json.loads(report_html)
        vcode = report_json['statusCode']
        if vcode!= 200:
            dd = wus(link)
        print(dd)

# %%
def wus(link):
    time.sleep(60)
    report = urlopen(link)
    report_html = report.read()
    report_json = json.loads(report_html)
    vcode = report_json['statusCode']
    print("Status Code:",vcode)
    if vcode!= 200:
        wus(link)
        
    dd1 = urlopen(link)
    dd2 = dd1.read()
    dd3 = json.loads(dd2)
    dd4 = dd3['data']['average']['firstView']['visualComplete']
    dd5 = int(dd4)
    
    return dd5
